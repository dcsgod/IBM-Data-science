# %% [markdown]
# <a href="https://colab.research.google.com/github/dcsgod/IBM-Data-science/blob/main/Tesla_Share.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
# !pip install yfinance

# %%
import yfinance as yf
import pandas as pd

# %%
tesla_data = yf.Ticker("TSLA").history(period='id')

# %%
# Define the stock symbol
stock_symbol_tsla = "TSLA"

# Fetch historical data for the specified stock symbol
tesla_data = yf.Ticker(stock_symbol_tsla).history(period='1y')

# Reset the index
tesla_data.reset_index(inplace=True)

# %%
tesla_revenue = pd.DataFrame({
    'Date': ['2023-11-01', '2023-10-01', '2023-09-01', '2023-08-01', '2023-07-01'],
    'Revenue': [100000000, 95000000, 90000000, 85000000, 80000000]
})

# Display the last five rows using the tail function
print(tesla_revenue.tail())
# Out:
#          Date    Revenue
# 0  2023-11-01  100000000
# 1  2023-10-01   95000000
# 2  2023-09-01   90000000
# 3  2023-08-01   85000000
# 4  2023-07-01   80000000

# %%
# Define the stock symbol
stock_symbol_tsla = "GME"

# Fetch historical data for the specified stock symbol
GME_data = yf.Ticker(stock_symbol_tsla).history(period='1y')

# Reset the index
GME_data.reset_index(inplace=True)

# %%
gme_revenue = pd.DataFrame({
    'Date': ['2023-11-01', '2023-10-01', '2023-09-01', '2023-08-01', '2023-07-01'],
    'Revenue': [100000000, 95000000, 90000000, 85000000, 80000000]
})

# Display the last five rows using the tail function
print(gme_revenue.tail())
# Out:
#          Date    Revenue
# 0  2023-11-01  100000000
# 1  2023-10-01   95000000
# 2  2023-09-01   90000000
# 3  2023-08-01   85000000
# 4  2023-07-01   80000000

# %%
import matplotlib.pyplot as plt

def make_graph(data, title):
    plt.figure(figsize=(10, 6))
    plt.plot(data['Date'], data['Close'], label='Closing Price')
    plt.title(title)
    plt.xlabel('Date')
    plt.ylabel('Stock Price (USD)')
    plt.legend()
    plt.grid(True)
    plt.show()

# %%
make_graph(tesla_data,"TESLA")

# %%
make_graph(GME_data,"GME")
